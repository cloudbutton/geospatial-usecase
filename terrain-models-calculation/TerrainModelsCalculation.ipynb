# %% [markdown]
# # Cloudbutton geospatial use case: 3D fuel mapping for wildfire risk assessment

# %%
import pylab
# from sklearn.naive_bayes import GaussianNB
# from sklearn import model_selection
# from sklearn.linear_model import LogisticRegression
# from sklearn.preprocessing import scale, StandardScaler
# from sklearn.metrics import silhouette_score
# from sklearn.cluster import KMeans
# from shapely.geometry import mapping
from IPython.display import Image
# from IPython.core.display import HTML
# from shapely.geometry import mapping
# import rasterio as rio
# from sklearn.pipeline import Pipeline
# from rasterio.mask import mask
# from rasterio.plot import show
# from rasterio.merge import merge
# from rasterio.plot import show
# from rasterio.plot import show_hist
# from rasterio.windows import Window
# from rasterio.plot import reshape_as_raster
# from rasterio.plot import reshape_as_image
from lithops.storage import Storage
import matplotlib.pyplot as plt
# import geopandas as gpd
import pandas as pd
import numpy as np
import lithops
import pathlib
# import shapely
import shutil
# import pickle
import subprocess
# import concurrent.futures
# import joblib
# import gdal
# import earthpy as ep
# import earthpy.spatial as es
import time
# import glob
# import ogr
import os
# import io
# import pdal
# import xarray as xr
import json
# from matplotlib.colors import ListedColormap, BoundaryNorm

# %%
DATA_BUCKET_TEST = {'optim-size': 'laz_test_size', 'no-partitioned': 'laz_no_particionado',
                    'well-partitioned': 'las_well_partitioned', 'partitioned':'las_partitioned'}
DATA_BUCKET_TYPE = {'optim-size':'optim-size-test', 'no-partitioned': 'test-no-partitioned',
                    'well-partitioned': 'well-partitioned-test', 'partitioned': 'partitioned-test'}

LOCAL_INPUT_DIR = fr'D:\data\{DATA_BUCKET_TEST["no-partitioned"]}\10GB' # \10GB\5GB\2GB\1GB\512MB\256MB\128MB, Modified

DATA_BUCKET = f'objects-geospatial-wildfirerisk-{DATA_BUCKET_TYPE["no-partitioned"]}' # Added
INPUT_DATA_PREFIX = f'data-example/' # Modified

# %% [markdown]
# Experiment parameters

# %%
FCC_WINDOW = 3
FCC_BREAKPOINT = 0.01

# %% [markdown]
# ---
# Upload dataset
# ---

# %%
storage = Storage()

# %%
bucket_objects = storage.list_keys(bucket=DATA_BUCKET)
for subdir, dirs, files in os.walk(LOCAL_INPUT_DIR):
    print(subdir)
    for file_name in files:
        key = os.path.join(INPUT_DATA_PREFIX, file_name)  # Added
        if key not in bucket_objects:   # Changed: if file_name not in bucket_objects:
            with open(os.path.join(subdir, file_name), 'rb') as file: #Changed
                print(f'\tUploading {key}...')
                data = file.read()
                storage.put_object(bucket=DATA_BUCKET, key=key, body=data)
                print('\tOk!')
        else:   # Added
            print(f'\tIt is already uploaded: {key}...')   # Added
print("Finished!")

# %% [markdown]
# ---
# Calculte DEM, DSM, CHM, FCC, Aspect and Slope
# ---

# %%
def calculate_models(obj, storage):
    import pdal
    from osgeo import gdal
    from scipy import ndimage
    import time

    start_t = time.time()
    # Create temporary file paths
    tmp_path_prefix = '/tmp/geo/'
    if os.path.exists(tmp_path_prefix):
        shutil.rmtree(tmp_path_prefix)
    for subpath in ['dsm', 'dem', 'chm', 'aspect', 'slope', 'fcc']:
        os.makedirs(os.path.join(tmp_path_prefix, subpath), exist_ok=True)

    las_tile_filename = pathlib.Path(obj.key).name
    tile_key = pathlib.Path(obj.key).stem

    # Save obj to file
    data = obj.data_stream.read()
    input_file_path = os.path.join(tmp_path_prefix, las_tile_filename)
    with open(input_file_path, 'wb') as file:
        file.write(data)

    # DSM pipeline
    dsm_file_path = os.path.join(tmp_path_prefix, 'dsm', tile_key + '.gtiff')
    dsm_pipeline_json = {
        "pipeline": [
            {
                "type": "readers.las",
                "filename": f"{input_file_path}",
                "spatialreference": "EPSG:25830"
            },
            {
                "type": "filters.reprojection",
                "in_srs": "EPSG:25830",
                "out_srs": "EPSG:25830"
            },
            {
                "type": "filters.outlier",
                "method": "radius",
                "radius": 1.0,
                "min_k": 4
            },
            {
                "type": "filters.range",
                # Classification equals 2 (corresponding to noise points in LAS).
                "limits": "Classification![7:7]"
            },
            {
                "type": "filters.range",
                "limits": "returnnumber[1:1]"
            },
            {
                "type": "writers.gdal",
                "gdaldriver": "GTiff",
                "nodata": "-9999",
                "output_type": "max",
                "resolution": 1,
                "filename": f"{dsm_file_path}"
            }
        ]
    }
    dsm_pipeline_json_str = json.dumps(dsm_pipeline_json, indent=4)
    pipeline = pdal.Pipeline(dsm_pipeline_json_str)
    pipeline.validate()
    pipeline.loglevel = 8
    print('Executing DSM pipeline...')
    result = pipeline.execute()
    print(result)

    # DEM pipeline
    dem_file_path = os.path.join(tmp_path_prefix, 'dem', tile_key + '.gtiff')
    dem_pipeline_json = {
        "pipeline": [
            {
                "type": "readers.las",
                "filename": f"{input_file_path}",
                "spatialreference": "EPSG:25830"
            },
            {
                "type": "filters.reprojection",
                "in_srs": "EPSG:25830",
                "out_srs": "EPSG:25830"
            },
            {
                "type": "filters.assign",
                "assignment": "Classification[:]=0"
            },
            {
                "type": "filters.elm"
            },
            {
                "type": "filters.outlier",
                "method": "radius",
                "radius": 1.0,
                "min_k": 4
            },
            {

                "type": "filters.smrf",
                "ignore": "Classification[7:7]",
                "slope": 0.2,
                "window": 16,
                "threshold": 0.45,
                "scalar": 1.2
            },
            {
                "type": "filters.range",
                # Classification equals 2 (corresponding to ground in LAS).
                "limits": "Classification[2:2]",
            },
            {
                "type": "writers.gdal",
                "gdaldriver": "GTiff",
                "nodata": "-9999",
                "output_type": "max",
                "resolution": 1,
                "filename": f"{dem_file_path}"
            }
        ]
    }
    dem_pipeline_json_str = json.dumps(dem_pipeline_json, indent=4)
    pipeline = pdal.Pipeline(dem_pipeline_json_str)
    pipeline.validate()  # Check if json options are good
    pipeline.loglevel = 8
    print('Executing DEM pipeline...')
    result = pipeline.execute()
    print(result)

    # calculate CHM
    chm_file_path = os.path.join(tmp_path_prefix, 'chm', tile_key + '.tiff')
    cmd = ['gdal_calc.py', '-A', dem_file_path, '-B', dsm_file_path,
           '--calc="B-A"', '--NoDataValue=0', '--outfile', chm_file_path]
    p = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, close_fds=True)
    stdout, stderr = p.communicate()
    print(stdout, stderr)
    # assert p.returncode == 0

    # calculate aspect
    aspect_file_path = os.path.join(tmp_path_prefix, 'aspect', tile_key + '.tiff')
    cmd = ['gdaldem', 'aspect', dem_file_path, aspect_file_path, '-compute_edges']
    p = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, close_fds=True)
    stdout, stderr = p.communicate()
    print(stdout, stderr)
    # assert p.returncode == 0

    # calculate slope
    slope_file_path = os.path.join(tmp_path_prefix, 'slope', tile_key + '.tiff')
    cmd = ['gdaldem', 'slope', dem_file_path, slope_file_path, '-compute_edges']
    p = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, close_fds=True)
    stdout, stderr = p.communicate()
    print(stdout, stderr)
    # assert p.returncode == 0

    # calculate FCC
    in_ds = gdal.Open(dem_file_path)
    rows = in_ds.RasterYSize
    cols = in_ds.RasterXSize
    in_band = in_ds.GetRasterBand(1)
    data = in_band.ReadAsArray(0, 0, cols, rows).astype(np.float)
    data[data > FCC_BREAKPOINT] = 1
    data[data <= FCC_BREAKPOINT] = 0

    # Computing fraction on the whole raster through a moving window.
    def _compute_fraction(array):
        nveg = np.sum(array == 1)
        total = len(array)
        out = (nveg/total)*100
        return(out)

    TCC = ndimage.generic_filter(data, _compute_fraction, size=FCC_WINDOW)

    gtiff_driver = gdal.GetDriverByName("GTiff")
    fcc_file_path = os.path.join(tmp_path_prefix, 'fcc', tile_key + '.tiff')
    out_ds = gtiff_driver.Create(fcc_file_path, cols, rows, 1, in_band.DataType)
    out_ds.SetProjection(in_ds.GetProjection())
    out_ds.SetGeoTransform(in_ds.GetGeoTransform())

    out_band = out_ds.GetRasterBand(1)
    out_band.WriteArray(TCC)
    # out_ds.BuildOverviews("Average", [2, 4, 8, 16, 32])
    out_ds.FlushCache()
    del in_ds, out_ds

    outputs = [dsm_file_path, dem_file_path, chm_file_path,
               aspect_file_path, slope_file_path, fcc_file_path]
    for output_path in outputs:
        if os.path.exists(output_path):
            with open(output_path, 'rb') as output_file:
                data = output_file.read()
                cos_key = output_path.replace(tmp_path_prefix, '')
                storage.put_object(bucket=DATA_BUCKET, key=cos_key, body=data)
        else:
            print(f'Failed to upload {output_path}')

    # out = subprocess.check_output(['find', '/tmp/geo/'])
    return f'Time: {time.time() - start_t} seconds -> Key: {obj.key}'

# %%
fexec = lithops.FunctionExecutor()
# Out:
# 2022-06-24 18:34:44,030 [INFO] lithops.config -- Lithops v2.6.0
# 2022-06-24 18:34:44,043 [INFO] lithops.storage.backends.ibm_cos.ibm_cos -- IBM COS client created - Region: eu-de
# 2022-06-24 18:34:44,044 [INFO] lithops.serverless.backends.ibm_cf.ibm_cf -- IBM CF client created - Region: eu-de - Namespace: my-geospatial-wildfirerisk_foundry-geospatial-wildfirerisk-1

# %%
fexec.map(calculate_models, f'cos://{DATA_BUCKET}/{INPUT_DATA_PREFIX}')
# Out:
# 2022-06-24 18:34:44,108 [INFO] lithops.invokers -- ExecutorID e8f58c-0 | JobID M000 - Selected Runtime: sararl27/lithops-wildfirerisk-3.9:0.1 - 2048MB
# 2022-06-24 18:34:45,763 [INFO] lithops.invokers -- ExecutorID e8f58c-0 | JobID M000 - Starting function invocation: calculate_models() - Total: 173 activations
# 2022-06-24 18:34:46,146 [INFO] lithops.invokers -- ExecutorID e8f58c-0 | JobID M000 - View execution logs at /tmp/lithops/logs/e8f58c-0-M000.log
# [<lithops.future.ResponseFuture at 0x7f70c768e970>,
#  <lithops.future.ResponseFuture at 0x7f7190c35ac0>,
#  <lithops.future.ResponseFuture at 0x7f7190cc0580>,
#  <lithops.future.ResponseFuture at 0x7f7190cc0550>,
#  <lithops.future.ResponseFuture at 0x7f7190cc0430>,
#  <lithops.future.ResponseFuture at 0x7f7190cc0490>,
#  <lithops.future.ResponseFuture at 0x7f7190cc04f0>,
#  <lithops.future.ResponseFuture at 0x7f7190cc0520>,
#  <lithops.future.ResponseFuture at 0x7f7190cc08b0>,
#  <lithops.future.ResponseFuture at 0x7f7190cc0850>,
#  <lithops.future.ResponseFuture at 0x7f7190df1ee0>,
#  <lithops.future.ResponseFuture at 0x7f7190df17f0>,
#  <lithops.future.ResponseFuture at 0x7f7190df1f70>,
#  <lithops.future.ResponseFuture at 0x7f7190d1fca0>,
#  <lithops.future.ResponseFuture at 0x7f7190d1fd60>,
#  <lithops.future.ResponseFuture at 0x7f7190d1fd30>,
#  <lithops.future.ResponseFuture at 0x7f7190d1fbe0>,
#  <lithops.future.ResponseFuture at 0x7f7190d1fcd0>,
#  <lithops.future.ResponseFuture at 0x7f7190d1fd00>,
#  <lithops.future.ResponseFuture at 0x7f7190d2baf0>,
#  <lithops.future.ResponseFuture at 0x7f7190d2b460>,
#  <lithops.future.ResponseFuture at 0x7f7190d2b430>,
#  <lithops.future.ResponseFuture at 0x7f7190d261c0>,
#  <lithops.future.ResponseFuture at 0x7f7190d261f0>,
#  <lithops.future.ResponseFuture at 0x7f7190d26040>,
#  <lithops.future.ResponseFuture at 0x7f7190d260a0>,
#  <lithops.future.ResponseFuture at 0x7f7190d26160>,
#  <lithops.future.ResponseFuture at 0x7f7190d26190>,
#  <lithops.future.ResponseFuture at 0x7f7190d264c0>,
#  <lithops.future.ResponseFuture at 0x7f7190d260d0>,
#  <lithops.future.ResponseFuture at 0x7f7190d264f0>,
#  <lithops.future.ResponseFuture at 0x7f7190d26c40>,
#  <lithops.future.ResponseFuture at 0x7f7190d26490>,
#  <lithops.future.ResponseFuture at 0x7f7190d26520>,
#  <lithops.future.ResponseFuture at 0x7f7190d26460>,
#  <lithops.future.ResponseFuture at 0x7f7190d26580>,
#  <lithops.future.ResponseFuture at 0x7f7190d268e0>,
#  <lithops.future.ResponseFuture at 0x7f7190c82250>,
#  <lithops.future.ResponseFuture at 0x7f7190c82b80>,
#  <lithops.future.ResponseFuture at 0x7f7190c82bb0>,
#  <lithops.future.ResponseFuture at 0x7f7190c82be0>,
#  <lithops.future.ResponseFuture at 0x7f7190d544f0>,
#  <lithops.future.ResponseFuture at 0x7f7190d54b50>,
#  <lithops.future.ResponseFuture at 0x7f7190d548e0>,
#  <lithops.future.ResponseFuture at 0x7f7190d54d00>,
#  <lithops.future.ResponseFuture at 0x7f7190d54ee0>,
#  <lithops.future.ResponseFuture at 0x7f7190d54a30>,
#  <lithops.future.ResponseFuture at 0x7f7190d54640>,
#  <lithops.future.ResponseFuture at 0x7f7190d54e50>,
#  <lithops.future.ResponseFuture at 0x7f7190d54940>,
#  <lithops.future.ResponseFuture at 0x7f7190d54040>,
#  <lithops.future.ResponseFuture at 0x7f7190d54910>,
#  <lithops.future.ResponseFuture at 0x7f7190d54460>,
#  <lithops.future.ResponseFuture at 0x7f7190d54bb0>,
#  <lithops.future.ResponseFuture at 0x7f7190d540d0>,
#  <lithops.future.ResponseFuture at 0x7f7190d54430>,
#  <lithops.future.ResponseFuture at 0x7f7190d54100>,
#  <lithops.future.ResponseFuture at 0x7f7190d549d0>,
#  <lithops.future.ResponseFuture at 0x7f7190d543d0>,
#  <lithops.future.ResponseFuture at 0x7f7190d54c10>,
#  <lithops.future.ResponseFuture at 0x7f7190d54580>,
#  <lithops.future.ResponseFuture at 0x7f7190d54670>,
#  <lithops.future.ResponseFuture at 0x7f7190d545e0>,
#  <lithops.future.ResponseFuture at 0x7f7190d54610>,
#  <lithops.future.ResponseFuture at 0x7f7190d5f0d0>,
#  <lithops.future.ResponseFuture at 0x7f7190d5f340>,
#  <lithops.future.ResponseFuture at 0x7f7190d5f9d0>,
#  <lithops.future.ResponseFuture at 0x7f7190d5f160>,
#  <lithops.future.ResponseFuture at 0x7f7190d5fa60>,
#  <lithops.future.ResponseFuture at 0x7f7190d5f550>,
#  <lithops.future.ResponseFuture at 0x7f7190d5fa30>,
#  <lithops.future.ResponseFuture at 0x7f7190d5fb20>,
#  <lithops.future.ResponseFuture at 0x7f7190d5f460>,
#  <lithops.future.ResponseFuture at 0x7f7190d5ff70>,
#  <lithops.future.ResponseFuture at 0x7f7190d5ff10>,
#  <lithops.future.ResponseFuture at 0x7f7190d5ffd0>,
#  <lithops.future.ResponseFuture at 0x7f7190d5ffa0>,
#  <lithops.future.ResponseFuture at 0x7f7190d5f430>,
#  <lithops.future.ResponseFuture at 0x7f7190ce9f10>,
#  <lithops.future.ResponseFuture at 0x7f7190ce9580>,
#  <lithops.future.ResponseFuture at 0x7f7190ce9340>,
#  <lithops.future.ResponseFuture at 0x7f7190ce96d0>,
#  <lithops.future.ResponseFuture at 0x7f7190ce93a0>,
#  <lithops.future.ResponseFuture at 0x7f7190ce9b80>,
#  <lithops.future.ResponseFuture at 0x7f7190ce9f40>,
#  <lithops.future.ResponseFuture at 0x7f7190ce9640>,
#  <lithops.future.ResponseFuture at 0x7f7190ce9670>,
#  <lithops.future.ResponseFuture at 0x7f7190ce9550>,
#  <lithops.future.ResponseFuture at 0x7f7190ce95b0>,
#  <lithops.future.ResponseFuture at 0x7f7190ce9610>,
#  <lithops.future.ResponseFuture at 0x7f7190ce95e0>,
#  <lithops.future.ResponseFuture at 0x7f7190ce9040>,
#  <lithops.future.ResponseFuture at 0x7f7190ce92e0>,
#  <lithops.future.ResponseFuture at 0x7f7190ce9310>,
#  <lithops.future.ResponseFuture at 0x7f7190ce4eb0>,
#  <lithops.future.ResponseFuture at 0x7f7190ce4e20>,
#  <lithops.future.ResponseFuture at 0x7f7190ce4e50>,
#  <lithops.future.ResponseFuture at 0x7f7190ce4b50>,
#  <lithops.future.ResponseFuture at 0x7f7190c92e20>,
#  <lithops.future.ResponseFuture at 0x7f7190c929a0>,
#  <lithops.future.ResponseFuture at 0x7f7190c92910>,
#  <lithops.future.ResponseFuture at 0x7f7190c92df0>,
#  <lithops.future.ResponseFuture at 0x7f7190c92e50>,
#  <lithops.future.ResponseFuture at 0x7f7190c8b0a0>,
#  <lithops.future.ResponseFuture at 0x7f7190c8b7f0>,
#  <lithops.future.ResponseFuture at 0x7f7190c8bc40>,
#  <lithops.future.ResponseFuture at 0x7f7190c9e700>,
#  <lithops.future.ResponseFuture at 0x7f7190c9ee50>,
#  <lithops.future.ResponseFuture at 0x7f7190c9e2b0>,
#  <lithops.future.ResponseFuture at 0x7f7190c9ef40>,
#  <lithops.future.ResponseFuture at 0x7f7190c9e3d0>,
#  <lithops.future.ResponseFuture at 0x7f7190d92c10>,
#  <lithops.future.ResponseFuture at 0x7f7190d92c40>,
#  <lithops.future.ResponseFuture at 0x7f7190d92ac0>,
#  <lithops.future.ResponseFuture at 0x7f7190d92b80>,
#  <lithops.future.ResponseFuture at 0x7f7190d92b20>,
#  <lithops.future.ResponseFuture at 0x7f7190d92be0>,
#  <lithops.future.ResponseFuture at 0x7f7190d92f40>,
#  <lithops.future.ResponseFuture at 0x7f7190d92070>,
#  <lithops.future.ResponseFuture at 0x7f7190d92040>,
#  <lithops.future.ResponseFuture at 0x7f7190d92430>,
#  <lithops.future.ResponseFuture at 0x7f7190d92460>,
#  <lithops.future.ResponseFuture at 0x7f7190d922e0>,
#  <lithops.future.ResponseFuture at 0x7f7190d923a0>,
#  <lithops.future.ResponseFuture at 0x7f7190d92340>,
#  <lithops.future.ResponseFuture at 0x7f7190d92400>,
#  <lithops.future.ResponseFuture at 0x7f7190d92760>,
#  <lithops.future.ResponseFuture at 0x7f7190d92af0>,
#  <lithops.future.ResponseFuture at 0x7f7190d92700>,
#  <lithops.future.ResponseFuture at 0x7f7190d92370>,
#  <lithops.future.ResponseFuture at 0x7f7190d87eb0>,
#  <lithops.future.ResponseFuture at 0x7f7190d87f70>,
#  <lithops.future.ResponseFuture at 0x7f7190d87f10>,
#  <lithops.future.ResponseFuture at 0x7f7190d87fd0>,
#  <lithops.future.ResponseFuture at 0x7f7193e65b20>,
#  <lithops.future.ResponseFuture at 0x7f7193e65be0>,
#  <lithops.future.ResponseFuture at 0x7f7193e7ec10>,
#  <lithops.future.ResponseFuture at 0x7f7193e7ebb0>,
#  <lithops.future.ResponseFuture at 0x7f7190e01820>,
#  <lithops.future.ResponseFuture at 0x7f7190e01040>,
#  <lithops.future.ResponseFuture at 0x7f7190e01070>,
#  <lithops.future.ResponseFuture at 0x7f7190e01370>,
#  <lithops.future.ResponseFuture at 0x7f7190e01760>,
#  <lithops.future.ResponseFuture at 0x7f7190e01bb0>,
#  <lithops.future.ResponseFuture at 0x7f7190e01850>,
#  <lithops.future.ResponseFuture at 0x7f7190e01880>,
#  <lithops.future.ResponseFuture at 0x7f7190e01b50>,
#  <lithops.future.ResponseFuture at 0x7f7190e01c10>,
#  <lithops.future.ResponseFuture at 0x7f7190e01f70>,
#  <lithops.future.ResponseFuture at 0x7f7190e01f10>,
#  <lithops.future.ResponseFuture at 0x7f7190e01fd0>,
#  <lithops.future.ResponseFuture at 0x7f7190e0e430>,
#  <lithops.future.ResponseFuture at 0x7f7190e0e2e0>,
#  <lithops.future.ResponseFuture at 0x7f7190e0ec10>,
#  <lithops.future.ResponseFuture at 0x7f7190e0ec40>,
#  <lithops.future.ResponseFuture at 0x7f7190e0eac0>,
#  <lithops.future.ResponseFuture at 0x7f7190e0eb80>,
#  <lithops.future.ResponseFuture at 0x7f7190e0eb20>,
#  <lithops.future.ResponseFuture at 0x7f7190e0ebe0>,
#  <lithops.future.ResponseFuture at 0x7f7190e0ef10>,
#  <lithops.future.ResponseFuture at 0x7f7190e0e3a0>,
#  <lithops.future.ResponseFuture at 0x7f7190e0e340>,
#  <lithops.future.ResponseFuture at 0x7f7190e0e400>,
#  <lithops.future.ResponseFuture at 0x7f7190e1b340>,
#  <lithops.future.ResponseFuture at 0x7f7190e1bc10>,
#  <lithops.future.ResponseFuture at 0x7f7190e1bc40>,
#  <lithops.future.ResponseFuture at 0x7f7190e1bac0>,
#  <lithops.future.ResponseFuture at 0x7f7190e1bb80>,
#  <lithops.future.ResponseFuture at 0x7f7190e1bb20>,
#  <lithops.future.ResponseFuture at 0x7f7190e1bbe0>,
#  <lithops.future.ResponseFuture at 0x7f7190e1bf40>,
#  <lithops.future.ResponseFuture at 0x7f7190e1b790>,
#  <lithops.future.ResponseFuture at 0x7f7190e1b730>]

# %%
res = fexec.get_result()
# Out:
# 2022-06-24 18:34:46,230 [INFO] lithops.wait -- ExecutorID e8f58c-0 - Getting results from 173 function activations
#     0%|          | 0/173
# 2022-06-24 18:40:31,186 [INFO] lithops.executors -- ExecutorID e8f58c-0 - Cleaning temporary data

# %%
max_t = [0,'']
for r in res:
    tmp = float(r.split(' ')[1])
    if tmp > max_t[0]:
        max_t[0] = tmp
        max_t[1] = r
    print(r)
    print('---')
# Out:
# Time: 192.18983006477356 seconds -> Key: data-example/PNOA_2016_CAT_328-4564_ORT-CLA-CIR.laz
# ---
# Time: 172.83635687828064 seconds -> Key: data-example/PNOA_2016_CAT_328-4564_ORT-CLA-COL.laz
# ---
# Time: 325.26327085494995 seconds -> Key: data-example/PNOA_2016_CAT_328-4566_ORT-CLA-CIR.laz
# ---
# Time: 215.73557949066162 seconds -> Key: data-example/PNOA_2016_CAT_328-4566_ORT-CLA-COL.laz
# ---
# Time: 227.38165831565857 seconds -> Key: data-example/PNOA_2016_CAT_328-4568_ORT-CLA-CIR.laz
# ---
# Time: 209.5528769493103 seconds -> Key: data-example/PNOA_2016_CAT_328-4568_ORT-CLA-COL.laz
# ---
# Time: 203.10607743263245 seconds -> Key: data-example/PNOA_2016_CAT_330-4554_ORT-CLA-CIR.laz
# ---
# Time: 192.04993104934692 seconds -> Key: data-example/PNOA_2016_CAT_330-4554_ORT-CLA-COL.laz
# ---
# Time: 217.34001469612122 seconds -> Key: data-example/PNOA_2016_CAT_330-4564_ORT-CLA-CIR.laz
# ---
# Time: 203.4444558620453 seconds -> Key: data-example/PNOA_2016_CAT_330-4564_ORT-CLA-COL.laz
# ---
# Time: 243.10203337669373 seconds -> Key: data-example/PNOA_2016_CAT_330-4566_ORT-CLA-CIR.laz
# ---
# Time: 262.10761046409607 seconds -> Key: data-example/PNOA_2016_CAT_330-4566_ORT-CLA-COL.laz
# ---
# Time: 157.13054394721985 seconds -> Key: data-example/PNOA_2016_CAT_330-4568_ORT-CLA-CIR.laz
# ---
# Time: 121.80756449699402 seconds -> Key: data-example/PNOA_2016_CAT_330-4568_ORT-CLA-COL.laz
# ---
# Time: 252.54402136802673 seconds -> Key: data-example/PNOA_2016_CAT_332-4548_ORT-CLA-CIR.laz
# ---
# Time: 168.44893503189087 seconds -> Key: data-example/PNOA_2016_CAT_332-4548_ORT-CLA-COL.laz
# ---
# Time: 227.07527875900269 seconds -> Key: data-example/PNOA_2016_CAT_332-4550_ORT-CLA-CIR.laz
# ---
# Time: 236.85713601112366 seconds -> Key: data-example/PNOA_2016_CAT_332-4550_ORT-CLA-COL.laz
# ---
# Time: 197.263258934021 seconds -> Key: data-example/PNOA_2016_CAT_332-4552_ORT-CLA-CIR.laz
# ---
# Time: 226.18762063980103 seconds -> Key: data-example/PNOA_2016_CAT_332-4552_ORT-CLA-COL.laz
# ---
# Time: 193.03260850906372 seconds -> Key: data-example/PNOA_2016_CAT_332-4554_ORT-CLA-CIR.laz
# ---
# Time: 201.35532140731812 seconds -> Key: data-example/PNOA_2016_CAT_332-4554_ORT-CLA-COL.laz
# ---
# Time: 331.252991437912 seconds -> Key: data-example/PNOA_2016_CAT_332-4558_ORT-CLA-CIR.laz
# ---
# Time: 210.21628665924072 seconds -> Key: data-example/PNOA_2016_CAT_332-4558_ORT-CLA-COL.laz
# ---
# Time: 179.4362416267395 seconds -> Key: data-example/PNOA_2016_CAT_332-4564_ORT-CLA-CIR.laz
# ---
# Time: 174.76851439476013 seconds -> Key: data-example/PNOA_2016_CAT_332-4564_ORT-CLA-COL.laz
# ---
# Time: 243.2012071609497 seconds -> Key: data-example/PNOA_2016_CAT_332-4566_ORT-CLA-CIR.laz
# ---
# Time: 222.78252410888672 seconds -> Key: data-example/PNOA_2016_CAT_332-4566_ORT-CLA-COL.laz
# ---
# Time: 188.48103022575378 seconds -> Key: data-example/PNOA_2016_CAT_332-4568_ORT-CLA-CIR.laz
# ---
# Time: 184.93222880363464 seconds -> Key: data-example/PNOA_2016_CAT_332-4568_ORT-CLA-COL.laz
# ---
# Time: 214.90649557113647 seconds -> Key: data-example/PNOA_2016_CAT_334-4548_ORT-CLA-CIR.laz
# ---
# Time: 178.27036452293396 seconds -> Key: data-example/PNOA_2016_CAT_334-4548_ORT-CLA-COL.laz
# ---
# Time: 216.1968915462494 seconds -> Key: data-example/PNOA_2016_CAT_334-4550_ORT-CLA-CIR.laz
# ---
# Time: 211.63724327087402 seconds -> Key: data-example/PNOA_2016_CAT_334-4550_ORT-CLA-COL.laz
# ---
# Time: 219.3702576160431 seconds -> Key: data-example/PNOA_2016_CAT_334-4552_ORT-CLA-CIR.laz
# ---
# Time: 214.6532289981842 seconds -> Key: data-example/PNOA_2016_CAT_334-4552_ORT-CLA-COL.laz
# ---
# Time: 172.59412479400635 seconds -> Key: data-example/PNOA_2016_CAT_334-4554_ORT-CLA-CIR.laz
# ---
# Time: 223.7762050628662 seconds -> Key: data-example/PNOA_2016_CAT_334-4554_ORT-CLA-COL.laz
# ---
# Time: 151.3892273902893 seconds -> Key: data-example/PNOA_2016_CAT_334-4564_ORT-CLA-CIR.laz
# ---
# Time: 278.2067058086395 seconds -> Key: data-example/PNOA_2016_CAT_334-4564_ORT-CLA-COL.laz
# ---
# Time: 218.43168878555298 seconds -> Key: data-example/PNOA_2016_CAT_334-4566_ORT-CLA-CIR.laz
# ---
# Time: 256.60412430763245 seconds -> Key: data-example/PNOA_2016_CAT_334-4566_ORT-CLA-COL.laz
# ---
# Time: 186.04821109771729 seconds -> Key: data-example/PNOA_2016_CAT_334-4568_ORT-CLA-CIR.laz
# ---
# Time: 172.73213958740234 seconds -> Key: data-example/PNOA_2016_CAT_334-4568_ORT-CLA-COL.laz
# ---
# Time: 110.0594744682312 seconds -> Key: data-example/PNOA_2016_CAT_336-4548_ORT-CLA-CIR.laz
# ---
# Time: 120.03893256187439 seconds -> Key: data-example/PNOA_2016_CAT_336-4548_ORT-CLA-COL.laz
# ---
# Time: 243.4910500049591 seconds -> Key: data-example/PNOA_2016_CAT_336-4550_ORT-CLA-CIR.laz
# ---
# Time: 223.42916870117188 seconds -> Key: data-example/PNOA_2016_CAT_336-4550_ORT-CLA-COL.laz
# ---
# Time: 193.67693209648132 seconds -> Key: data-example/PNOA_2016_CAT_336-4552_ORT-CLA-CIR.laz
# ---
# Time: 204.40095829963684 seconds -> Key: data-example/PNOA_2016_CAT_336-4552_ORT-CLA-COL.laz
# ---
# Time: 275.3034040927887 seconds -> Key: data-example/PNOA_2016_CAT_336-4554_ORT-CLA-CIR.laz
# ---
# Time: 278.2124009132385 seconds -> Key: data-example/PNOA_2016_CAT_336-4554_ORT-CLA-COL.laz
# ---
# Time: 248.74454617500305 seconds -> Key: data-example/PNOA_2016_CAT_336-4558_ORT-CLA-COL.laz
# ---
# Time: 214.82142066955566 seconds -> Key: data-example/PNOA_2016_CAT_336-4562_ORT-CLA-COL.laz
# ---
# Time: 215.74957394599915 seconds -> Key: data-example/PNOA_2016_CAT_336-4564_ORT-CLA-CIR.laz
# ---
# Time: 194.9042785167694 seconds -> Key: data-example/PNOA_2016_CAT_336-4564_ORT-CLA-COL.laz
# ---
# Time: 223.04682159423828 seconds -> Key: data-example/PNOA_2016_CAT_336-4568_ORT-CLA-CIR.laz
# ---
# Time: 200.23796248435974 seconds -> Key: data-example/PNOA_2016_CAT_336-4568_ORT-CLA-COL.laz
# ---
# Time: 147.7270154953003 seconds -> Key: data-example/PNOA_2016_CAT_338-4548_ORT-CLA-CIR.laz
# ---
# Time: 105.11756181716919 seconds -> Key: data-example/PNOA_2016_CAT_338-4548_ORT-CLA-COL.laz
# ---
# Time: 297.03698086738586 seconds -> Key: data-example/PNOA_2016_CAT_338-4550_ORT-CLA-CIR.laz
# ---
# Time: 271.7834599018097 seconds -> Key: data-example/PNOA_2016_CAT_338-4550_ORT-CLA-COL.laz
# ---
# Time: 185.00122475624084 seconds -> Key: data-example/PNOA_2016_CAT_338-4552_ORT-CLA-CIR.laz
# ---
# Time: 299.13235878944397 seconds -> Key: data-example/PNOA_2016_CAT_338-4552_ORT-CLA-COL.laz
# ---
# Time: 197.16491675376892 seconds -> Key: data-example/PNOA_2016_CAT_338-4554_ORT-CLA-CIR.laz
# ---
# Time: 222.32924389839172 seconds -> Key: data-example/PNOA_2016_CAT_338-4554_ORT-CLA-COL.laz
# ---
# Time: 204.37535190582275 seconds -> Key: data-example/PNOA_2016_CAT_338-4564_ORT-CLA-CIR.laz
# ---
# Time: 292.62399554252625 seconds -> Key: data-example/PNOA_2016_CAT_338-4564_ORT-CLA-COL.laz
# ---
# Time: 221.1941430568695 seconds -> Key: data-example/PNOA_2016_CAT_338-4568_ORT-CLA-CIR.laz
# ---
# Time: 218.74806904792786 seconds -> Key: data-example/PNOA_2016_CAT_338-4568_ORT-CLA-COL.laz
# ---
# Time: 227.73928928375244 seconds -> Key: data-example/PNOA_2016_CAT_340-4550_ORT-CLA-CIR.laz
# ---
# Time: 205.20263051986694 seconds -> Key: data-example/PNOA_2016_CAT_340-4550_ORT-CLA-COL.laz
# ---
# Time: 191.24073243141174 seconds -> Key: data-example/PNOA_2016_CAT_340-4552_ORT-CLA-CIR.laz
# ---
# Time: 227.88006973266602 seconds -> Key: data-example/PNOA_2016_CAT_340-4552_ORT-CLA-COL.laz
# ---
# Time: 157.5180525779724 seconds -> Key: data-example/PNOA_2016_CAT_340-4554_ORT-CLA-CIR.laz
# ---
# Time: 199.33726453781128 seconds -> Key: data-example/PNOA_2016_CAT_340-4554_ORT-CLA-COL.laz
# ---
# Time: 222.64677810668945 seconds -> Key: data-example/PNOA_2016_CAT_340-4562_ORT-CLA-CIR.laz
# ---
# Time: 236.75565695762634 seconds -> Key: data-example/PNOA_2016_CAT_340-4562_ORT-CLA-COL.laz
# ---
# Time: 190.46643924713135 seconds -> Key: data-example/PNOA_2016_CAT_340-4564_ORT-CLA-CIR.laz
# ---
# Time: 204.22715616226196 seconds -> Key: data-example/PNOA_2016_CAT_340-4564_ORT-CLA-COL.laz
# ---
# Time: 220.93187642097473 seconds -> Key: data-example/PNOA_2016_CAT_340-4568_ORT-CLA-CIR.laz
# ---
# Time: 229.2609508037567 seconds -> Key: data-example/PNOA_2016_CAT_340-4568_ORT-CLA-COL.laz
# ---
# Time: 176.95464253425598 seconds -> Key: data-example/PNOA_2016_CAT_342-4550_ORT-CLA-CIR.laz
# ---
# Time: 191.94201612472534 seconds -> Key: data-example/PNOA_2016_CAT_342-4550_ORT-CLA-COL.laz
# ---
# Time: 203.43466138839722 seconds -> Key: data-example/PNOA_2016_CAT_342-4552_ORT-CLA-CIR.laz
# ---
# Time: 212.66151309013367 seconds -> Key: data-example/PNOA_2016_CAT_342-4552_ORT-CLA-COL.laz
# ---
# Time: 221.58118605613708 seconds -> Key: data-example/PNOA_2016_CAT_342-4554_ORT-CLA-CIR.laz
# ---
# Time: 192.1131670475006 seconds -> Key: data-example/PNOA_2016_CAT_342-4554_ORT-CLA-COL.laz
# ---
# Time: 167.78950572013855 seconds -> Key: data-example/PNOA_2016_CAT_344-4548_ORT-CLA-CIR.laz
# ---
# Time: 169.1518132686615 seconds -> Key: data-example/PNOA_2016_CAT_344-4548_ORT-CLA-COL.laz
# ---
# Time: 191.59714484214783 seconds -> Key: data-example/PNOA_2016_CAT_344-4550_ORT-CLA-CIR.laz
# ---
# Time: 259.26164650917053 seconds -> Key: data-example/PNOA_2016_CAT_344-4550_ORT-CLA-COL.laz
# ---
# Time: 185.76574873924255 seconds -> Key: data-example/PNOA_2016_CAT_344-4552_ORT-CLA-CIR.laz
# ---
# Time: 174.9924237728119 seconds -> Key: data-example/PNOA_2016_CAT_344-4552_ORT-CLA-COL.laz
# ---
# Time: 202.3167109489441 seconds -> Key: data-example/PNOA_2016_CAT_344-4554_ORT-CLA-CIR.laz
# ---
# Time: 219.82735085487366 seconds -> Key: data-example/PNOA_2016_CAT_344-4554_ORT-CLA-COL.laz
# ---
# Time: 257.97540974617004 seconds -> Key: data-example/PNOA_2016_CAT_344-4558_ORT-CLA-CIR.laz
# ---
# Time: 235.56375288963318 seconds -> Key: data-example/PNOA_2016_CAT_344-4558_ORT-CLA-COL.laz
# ---
# Time: 136.4809730052948 seconds -> Key: data-example/PNOA_2016_CAT_346-4548_ORT-CLA-CIR.laz
# ---
# Time: 143.80498385429382 seconds -> Key: data-example/PNOA_2016_CAT_346-4548_ORT-CLA-COL.laz
# ---
# Time: 206.77816104888916 seconds -> Key: data-example/PNOA_2016_CAT_346-4550_ORT-CLA-CIR.laz
# ---
# Time: 166.82064723968506 seconds -> Key: data-example/PNOA_2016_CAT_346-4550_ORT-CLA-COL.laz
# ---
# Time: 174.5132074356079 seconds -> Key: data-example/PNOA_2016_CAT_346-4552_ORT-CLA-CIR.laz
# ---
# Time: 156.8924720287323 seconds -> Key: data-example/PNOA_2016_CAT_346-4552_ORT-CLA-COL.laz
# ---
# Time: 217.0423378944397 seconds -> Key: data-example/PNOA_2016_CAT_346-4554_ORT-CLA-CIR.laz
# ---
# Time: 204.9277081489563 seconds -> Key: data-example/PNOA_2016_CAT_346-4554_ORT-CLA-COL.laz
# ---
# Time: 290.09338426589966 seconds -> Key: data-example/PNOA_2016_CAT_346-4556_ORT-CLA-CIR.laz
# ---
# Time: 245.70732736587524 seconds -> Key: data-example/PNOA_2016_CAT_346-4556_ORT-CLA-COL.laz
# ---
# Time: 308.04224157333374 seconds -> Key: data-example/PNOA_2016_CAT_346-4558_ORT-CLA-CIR.laz
# ---
# Time: 280.06201219558716 seconds -> Key: data-example/PNOA_2016_CAT_346-4558_ORT-CLA-COL.laz
# ---
# Time: 234.39582014083862 seconds -> Key: data-example/PNOA_2016_CAT_346-4562_ORT-CLA-COL.laz
# ---
# Time: 127.0680034160614 seconds -> Key: data-example/PNOA_2016_CAT_348-4550_ORT-CLA-CIR.laz
# ---
# Time: 124.01180362701416 seconds -> Key: data-example/PNOA_2016_CAT_348-4550_ORT-CLA-COL.laz
# ---
# Time: 201.5667531490326 seconds -> Key: data-example/PNOA_2016_CAT_348-4552_ORT-CLA-CIR.laz
# ---
# Time: 202.6684272289276 seconds -> Key: data-example/PNOA_2016_CAT_348-4552_ORT-CLA-COL.laz
# ---
# Time: 221.1647002696991 seconds -> Key: data-example/PNOA_2016_CAT_348-4554_ORT-CLA-CIR.laz
# ---
# Time: 223.85881853103638 seconds -> Key: data-example/PNOA_2016_CAT_348-4554_ORT-CLA-COL.laz
# ---
# Time: 327.7502398490906 seconds -> Key: data-example/PNOA_2016_CAT_348-4556_ORT-CLA-CIR.laz
# ---
# Time: 244.17463421821594 seconds -> Key: data-example/PNOA_2016_CAT_348-4556_ORT-CLA-COL.laz
# ---
# Time: 95.65201139450073 seconds -> Key: data-example/PNOA_2016_CAT_350-4550_ORT-CLA-CIR.laz
# ---
# Time: 135.12077593803406 seconds -> Key: data-example/PNOA_2016_CAT_350-4550_ORT-CLA-COL.laz
# ---
# Time: 189.906800031662 seconds -> Key: data-example/PNOA_2016_CAT_350-4552_ORT-CLA-CIR.laz
# ---
# Time: 139.59113097190857 seconds -> Key: data-example/PNOA_2016_CAT_350-4552_ORT-CLA-COL.laz
# ---
# Time: 201.51500034332275 seconds -> Key: data-example/PNOA_2016_CAT_350-4566_ORT-CLA-CIR.laz
# ---
# Time: 203.77308678627014 seconds -> Key: data-example/PNOA_2016_CAT_350-4566_ORT-CLA-COL.laz
# ---
# Time: 214.0580084323883 seconds -> Key: data-example/PNOA_2016_CAT_350-4568_ORT-CLA-COL.laz
# ---
# Time: 117.8526074886322 seconds -> Key: data-example/PNOA_2016_CAT_350-4572_ORT-CLA-CIR.laz
# ---
# Time: 183.8953173160553 seconds -> Key: data-example/PNOA_2016_CAT_350-4572_ORT-CLA-COL.laz
# ---
# Time: 144.64103150367737 seconds -> Key: data-example/PNOA_2016_CAT_352-4552_ORT-CLA-CIR.laz
# ---
# Time: 101.04201602935791 seconds -> Key: data-example/PNOA_2016_CAT_352-4552_ORT-CLA-COL.laz
# ---
# Time: 199.62218523025513 seconds -> Key: data-example/PNOA_2016_CAT_354-4554_ORT-CLA-CIR.laz
# ---
# Time: 169.3861837387085 seconds -> Key: data-example/PNOA_2016_CAT_354-4554_ORT-CLA-COL.laz
# ---
# Time: 306.4095046520233 seconds -> Key: data-example/PNOA_2016_CAT_354-4566_ORT-CLA-CIR.laz
# ---
# Time: 230.11170625686646 seconds -> Key: data-example/PNOA_2016_CAT_354-4566_ORT-CLA-COL.laz
# ---
# Time: 192.0678780078888 seconds -> Key: data-example/PNOA_2016_CAT_354-4568_ORT-CLA-CIR.laz
# ---
# Time: 182.58535933494568 seconds -> Key: data-example/PNOA_2016_CAT_354-4568_ORT-CLA-COL.laz
# ---
# Time: 173.56300377845764 seconds -> Key: data-example/PNOA_2016_CAT_354-4572_ORT-CLA-CIR.laz
# ---
# Time: 166.90409135818481 seconds -> Key: data-example/PNOA_2016_CAT_354-4572_ORT-CLA-COL.laz
# ---
# Time: 117.50651621818542 seconds -> Key: data-example/PNOA_2016_CAT_356-4554_ORT-CLA-CIR.laz
# ---
# Time: 150.5449788570404 seconds -> Key: data-example/PNOA_2016_CAT_356-4554_ORT-CLA-COL.laz
# ---
# Time: 202.47067260742188 seconds -> Key: data-example/PNOA_2016_CAT_356-4568_ORT-CLA-CIR.laz
# ---
# Time: 208.04127383232117 seconds -> Key: data-example/PNOA_2016_CAT_356-4568_ORT-CLA-COL.laz
# ---
# Time: 179.6365737915039 seconds -> Key: data-example/PNOA_2016_CAT_356-4572_ORT-CLA-CIR.laz
# ---
# Time: 190.972829580307 seconds -> Key: data-example/PNOA_2016_CAT_356-4572_ORT-CLA-COL.laz
# ---
# Time: 182.56154608726501 seconds -> Key: data-example/PNOA_2016_CAT_358-4568_ORT-CLA-CIR.laz
# ---
# Time: 215.28886485099792 seconds -> Key: data-example/PNOA_2016_CAT_358-4568_ORT-CLA-COL.laz
# ---
# Time: 222.7360212802887 seconds -> Key: data-example/PNOA_2016_CAT_358-4572_ORT-CLA-CIR.laz
# ---
# Time: 208.79295778274536 seconds -> Key: data-example/PNOA_2016_CAT_358-4572_ORT-CLA-COL.laz
# ---
# Time: 220.81659078598022 seconds -> Key: data-example/PNOA_2016_CAT_360-4572_ORT-CLA-CIR.laz
# ---
# Time: 227.4609351158142 seconds -> Key: data-example/PNOA_2016_CAT_360-4572_ORT-CLA-COL.laz
# ---
# Time: 225.5995762348175 seconds -> Key: data-example/PNOA_2016_CAT_362-4564_ORT-CLA-CIR.laz
# ---
# Time: 235.58082962036133 seconds -> Key: data-example/PNOA_2016_CAT_362-4568_ORT-CLA-COL.laz
# ---
# Time: 160.05680561065674 seconds -> Key: data-example/PNOA_2016_CAT_362-4572_ORT-CLA-CIR.laz
# ---
# Time: 205.08409929275513 seconds -> Key: data-example/PNOA_2016_CAT_362-4572_ORT-CLA-COL.laz
# ---
# Time: 196.33910942077637 seconds -> Key: data-example/PNOA_2016_CAT_364-4568_ORT-CLA-CIR.laz
# ---
# Time: 120.45059990882874 seconds -> Key: data-example/PNOA_2016_CAT_364-4568_ORT-CLA-COL.laz
# ---
# Time: 159.0933711528778 seconds -> Key: data-example/PNOA_2016_CAT_366-4556_ORT-CLA-CIR.laz
# ---
# Time: 220.78072214126587 seconds -> Key: data-example/PNOA_2016_CAT_366-4556_ORT-CLA-COL.laz
# ---
# Time: 161.94279980659485 seconds -> Key: data-example/PNOA_2016_CAT_366-4572_ORT-CLA-CIR.laz
# ---
# Time: 165.37567472457886 seconds -> Key: data-example/PNOA_2016_CAT_366-4572_ORT-CLA-COL.laz
# ---
# Time: 193.13024711608887 seconds -> Key: data-example/PNOA_2016_CAT_368-4558_ORT-CLA-CIR.laz
# ---
# Time: 221.2471616268158 seconds -> Key: data-example/PNOA_2016_CAT_368-4558_ORT-CLA-COL.laz
# ---
# Time: 107.17080903053284 seconds -> Key: data-example/PNOA_2016_CAT_370-4558_ORT-CLA-CIR.laz
# ---
# Time: 145.68707656860352 seconds -> Key: data-example/PNOA_2016_CAT_370-4558_ORT-CLA-COL.laz
# ---
# Time: 182.11003851890564 seconds -> Key: data-example/PNOA_2016_CAT_374-4560_ORT-CLA-CIR.laz
# ---
# Time: 128.22214269638062 seconds -> Key: data-example/PNOA_2016_CAT_374-4560_ORT-CLA-COL.laz
# ---
# Time: 91.68222689628601 seconds -> Key: data-example/PNOA_2016_CAT_376-4560_ORT-CLA-CIR.laz
# ---
# Time: 97.70670318603516 seconds -> Key: data-example/PNOA_2016_CAT_376-4560_ORT-CLA-COL.laz
# ---
# Time: 198.71453309059143 seconds -> Key: data-example/PNOA_2016_CAT_376-4564_ORT-CLA-COL.laz
# ---
# Time: 215.63994646072388 seconds -> Key: data-example/PNOA_2016_CAT_380-4562_ORT-CLA-CIR.laz
# ---
# Time: 174.51671051979065 seconds -> Key: data-example/PNOA_2016_CAT_380-4562_ORT-CLA-COL.laz
# ---
# Time: 122.06408739089966 seconds -> Key: data-example/PNOA_2016_CAT_382-4562_ORT-CLA-CIR.laz
# ---
# Time: 204.73366808891296 seconds -> Key: data-example/PNOA_2016_CAT_382-4562_ORT-CLA-COL.laz
# ---

# %%
print(f'Max = {max_t[1]}')
# Out:
# Max = Time: 331.252991437912 seconds -> Key: data-example/PNOA_2016_CAT_332-4558_ORT-CLA-CIR.laz

# %% [markdown]
# ---
# Scalability
# ---

# %%
def get_process_cost(fexec):
    import pandas as pd
    df = pd.read_csv(fexec.log_path)
    cost = float(df[df["Job_ID"] == "Summary"]["Cost"])
    return cost

# %% [markdown]
# #### Time “calculate_models”

# %%
# Statistics:
endTime = set()
startTime = set()

for future in fexec.futures:
    for key in future.stats.keys():
        if key.endswith("worker_func_start_tstamp"):
            startTime.add(future.stats[key])
        if key.endswith("worker_func_end_tstamp"):
            endTime.add(future.stats[key])

timeExec = max(endTime) - min(startTime)

# %%
print(f"Time: {timeExec} seconds")
# Out:
# Time: 340.4002516269684 seconds

# %%
fexec.plot(dst="plots/scalability_wildFireRisk")
# Out:
# 2022-06-24 18:40:32,311 [INFO] lithops.executors -- ExecutorID e8f58c-0 - Creating execution plots

# %%
Image(filename="plots/scalability_wildFireRisk_histogram.png")

# %%
Image(filename="plots/scalability_wildFireRisk_timeline.png")

# %% [markdown]
# #### Cost "calculate_models"

# %%
fexec.job_summary()
# Out:
# 2022-06-24 18:40:33,316 [INFO] lithops.executors -- View log file logs at /tmp/lithops/logs/2022-06-24_18:40:33.csv

# %%
pd.read_csv(fexec.log_path)
# Out:
#     Job_ID          Function  Invocations  Memory(MB)  AvgRuntime      Cost  \
# 0     M000  calculate_models          173      354304  202.250257  1.189636
# 1  Summary                            173      354304  202.250257  1.189636
#
#   CloudObjects
# 0
# 1            0

# %%
cost_interpolation = get_process_cost(fexec)
print(f"The experiment cost of 'calculate_models' ${cost_interpolation:.4f}.")
# Out:
# The experiment cost of 'calculate_models' $1.1896.

# %% [markdown]
# ---
# Throughput
# ---

# %%
fexec = lithops.FunctionExecutor()
storage = Storage()
# Out:
# 2022-06-24 18:40:33,550 [INFO] lithops.config -- Lithops v2.6.0
# 2022-06-24 18:40:33,566 [INFO] lithops.storage.backends.ibm_cos.ibm_cos -- IBM COS client created - Region: eu-de
# 2022-06-24 18:40:33,568 [INFO] lithops.serverless.backends.ibm_cf.ibm_cf -- IBM CF client created - Region: eu-de - Namespace: my-geospatial-wildfirerisk_foundry-geospatial-wildfirerisk-1
# 2022-06-24 18:40:33,576 [INFO] lithops.storage.backends.ibm_cos.ibm_cos -- IBM COS client created - Region: eu-de

# %% [markdown]
# ### Read

# %%
def storage_performance_read(key_name, storage):
    get_t0 = time.time()
    storage.get_object(bucket=DATA_BUCKET, key=key_name)
    get_t1 = time.time()
    get_sz = len(key_name)
    read_bandwidth_mb = get_sz / (get_t1 - get_t0) / 1e6

    stats = {'t0': get_t0, 't1': get_t1, 'bandwidth': read_bandwidth_mb, 'size': get_sz}

    return stats

# %%
data_file_read = [str(obj['Key']) for obj in storage.list_objects(DATA_BUCKET)
                  if str(obj['Key']).endswith('.laz') or str(obj['Key']).endswith('.las')]

fexecR = lithops.FunctionExecutor()
fs = fexecR.map(storage_performance_read, data_file_read)
read_results = fexecR.get_result(fs=fs)
# Out:
# 2022-06-24 18:40:34,678 [INFO] lithops.config -- Lithops v2.6.0
# 2022-06-24 18:40:34,688 [INFO] lithops.storage.backends.ibm_cos.ibm_cos -- IBM COS client created - Region: eu-de
# 2022-06-24 18:40:34,690 [INFO] lithops.serverless.backends.ibm_cf.ibm_cf -- IBM CF client created - Region: eu-de - Namespace: my-geospatial-wildfirerisk_foundry-geospatial-wildfirerisk-1
# 2022-06-24 18:40:34,691 [INFO] lithops.invokers -- ExecutorID e8f58c-2 | JobID M000 - Selected Runtime: sararl27/lithops-wildfirerisk-3.9:0.1 - 2048MB
# 2022-06-24 18:40:35,184 [INFO] lithops.invokers -- ExecutorID e8f58c-2 | JobID M000 - Starting function invocation: storage_performance_read() - Total: 173 activations
# 2022-06-24 18:40:35,493 [INFO] lithops.invokers -- ExecutorID e8f58c-2 | JobID M000 - View execution logs at /tmp/lithops/logs/e8f58c-2-M000.log
# 2022-06-24 18:40:35,534 [INFO] lithops.wait -- ExecutorID e8f58c-2 - Getting results from 173 function activations
#     0%|          | 0/173
# 2022-06-24 18:40:49,243 [INFO] lithops.executors -- ExecutorID e8f58c-2 - Cleaning temporary data

# %% [markdown]
# ### Write

# %%
def storage_performance_write(obj, size_file, storage):
    data = obj.data_stream.read()
    put_sz = size_file # Modified, get the size in bytes of the data to upload
    put_t0 = time.time()
    storage.put_object(bucket=DATA_BUCKET,  key=obj.key, body=data)
    put_t1 = time.time()
    write_bandwidth_mb = put_sz / (put_t1 - put_t0) / 1e6

    stats = {'t0': put_t0, 't1': put_t1, 'bandwidth': write_bandwidth_mb, 'size': put_sz}

    return stats

# %%
data_file_write = [{'obj':(f'cos://{DATA_BUCKET}/'+obj["Key"]), 'size_file': obj['Size']}
                   for obj in storage.list_objects(DATA_BUCKET)
                   if str(obj['Key']).endswith('.tiff') or str(obj['Key']).endswith('.gtiff')]

fexecW = lithops.FunctionExecutor()
fs = fexecW.map(storage_performance_write, data_file_write)
write_results = fexecW.get_result(fs=fs)
# Out:
# 2022-06-24 18:40:50,025 [INFO] lithops.config -- Lithops v2.6.0
# 2022-06-24 18:40:50,044 [INFO] lithops.storage.backends.ibm_cos.ibm_cos -- IBM COS client created - Region: eu-de
# 2022-06-24 18:40:50,046 [INFO] lithops.serverless.backends.ibm_cf.ibm_cf -- IBM CF client created - Region: eu-de - Namespace: my-geospatial-wildfirerisk_foundry-geospatial-wildfirerisk-1
# 2022-06-24 18:40:50,047 [INFO] lithops.invokers -- ExecutorID e8f58c-3 | JobID M000 - Selected Runtime: sararl27/lithops-wildfirerisk-3.9:0.1 - 2048MB
# 2022-06-24 18:40:51,396 [INFO] lithops.invokers -- ExecutorID e8f58c-3 | JobID M000 - Starting function invocation: storage_performance_write() - Total: 1013 activations
# 2022-06-24 18:40:53,806 [INFO] lithops.invokers -- ExecutorID e8f58c-3 | JobID M000 - View execution logs at /tmp/lithops/logs/e8f58c-3-M000.log
# 2022-06-24 18:40:53,989 [INFO] lithops.wait -- ExecutorID e8f58c-3 - Getting results from 1013 function activations
#     0%|          | 0/1013
# 2022-06-24 18:41:16,703 [INFO] lithops.executors -- ExecutorID e8f58c-3 - Cleaning temporary data

# %% [markdown]
# ### Resume

# %%
def create_agg_bdwth_plot(res_write, res_read, dst):
    def compute_times_rates(start_time, d):
        x = np.array(d)
        tzero = start_time
        tr_start_time = x[:, 0] - tzero
        tr_end_time = x[:, 1] - tzero
        rate = x[:, 2]

        N = len(tr_start_time)
        runtime_rate_hist = np.zeros((N, len(runtime_bins)))

        for i in range(N):
            s = tr_start_time[i]
            e = tr_end_time[i]
            a, b = np.searchsorted(runtime_bins, [s, e])
            if b-a > 0:
                runtime_rate_hist[i, a:b] = rate[i]

        return {'start_time': tr_start_time,
                'end_time': tr_end_time,
                'rate': rate,
                'runtime_rate_hist': runtime_rate_hist}

    start_time = min((min(t['t0'] for t in res_write), (min(t['t0'] for t in res_read)))) - 1

    fig = pylab.figure(figsize=(8, 6))
    ax = fig.add_subplot(1, 1, 1)
    for datum, l in [(res_write, 'Aggregate Write Bandwidth'), (res_read, 'Aggregate Read Bandwidth')]:
        mb_rates = [(res['t0'], res['t1'], res['bandwidth']) for res in datum]
        max_seconds = int(max([mr[1]-start_time for mr in mb_rates])*1.2)
        max_seconds = 8 * round(max_seconds/8)
        runtime_bins = np.linspace(0, max_seconds, max_seconds)

        mb_rates_hist = compute_times_rates(start_time, mb_rates)

        ax.plot(mb_rates_hist['runtime_rate_hist'].sum(axis=0)/1000, label=l)

    ax.set_xlabel('Execution Time (sec)')
    ax.set_ylabel("GB/sec")
    ax.set_xlim(0, )
    ax.set_ylim(0, )
    pylab.legend()
    pylab.grid(True, axis='y')

    dst = os.path.expanduser(dst) if '~' in dst else dst
    fig.tight_layout()
    fig.savefig(dst, format='png')

# %%
create_agg_bdwth_plot(write_results, read_results, './plots/throughput_storage_kpi.png')
Image(filename="plots/throughput_storage_kpi.png")

# %%
def calc_mean_throughput(dict):
    res = 0
    for val in dict:
        res += val['bandwidth']
    return (res/len(dict))

# %%
print(f'Mean throughput read: {calc_mean_throughput(read_results)} MB/s\nMean throughput write: {calc_mean_throughput(write_results)} MB/s')
# Out:
# Mean throughput read: 6.890030761276354e-05 MB/s
# Mean throughput write: 34.56599659555448 MB/s

# %% [markdown]
# ### Time throughput

# %%
# Statistics:
def calculate_time(aux_fexec):
    endTime = set()
    startTime = set()

    for future in aux_fexec.futures:
        for key in future.stats.keys():
            if key.endswith("worker_func_start_tstamp"):
                startTime.add(future.stats[key])
            if key.endswith("worker_func_end_tstamp"):
                endTime.add(future.stats[key])

    return max(endTime) - min(startTime)

# %%
print(f"Time reading: {calculate_time(fexecR)} seconds\nTime writing: {calculate_time(fexecW)} seconds")
# Out:
# Time reading: 10.448554277420044 seconds
# Time writing: 21.87249255180359 seconds

# %% [markdown]
# ### Read throughput

# %%
fexecR.plot(dst="plots/scalability_throughput_read")
# Out:
# 2022-06-24 18:41:17,409 [INFO] lithops.executors -- ExecutorID e8f58c-2 - Creating execution plots

# %%
Image(filename="plots/scalability_throughput_read_histogram.png")

# %%
Image(filename="plots/scalability_throughput_read_timeline.png")

# %% [markdown]
# ### Write throughput

# %%
fexecW.plot(dst="plots/scalability_throughput_write")
# Out:
# 2022-06-24 18:41:18,107 [INFO] lithops.executors -- ExecutorID e8f58c-3 - Creating execution plots

# %%
Image(filename="plots/scalability_throughput_write_histogram.png")

# %%
Image(filename="plots/scalability_throughput_write_timeline.png")

# %% [markdown]
# ### Cost throughput

# %%
fexecR.job_summary()
# Out:
# 2022-06-24 18:46:33,304 [INFO] lithops.executors -- View log file logs at /tmp/lithops/logs/2022-06-24_18:41:19.csv

# %%
pd.read_csv(fexecR.log_path)
# Out:
#     Job_ID                  Function  Invocations  Memory(MB)  AvgRuntime  \
# 0     M000  storage_performance_read          173      354304    1.092221
# 1  Summary                                    173      354304    1.092221
#
#        Cost CloudObjects
# 0  0.006424
# 1  0.006424          0.0

# %%
costR = get_process_cost(fexecR)

# %%
fexecW.job_summary()
# Out:
# 2022-06-24 18:46:35,160 [INFO] lithops.executors -- View log file logs at /tmp/lithops/logs/2022-06-24_18:41:19.csv

# %%
pd.read_csv(fexecW.log_path)
# Out:
#     Job_ID                   Function  Invocations  Memory(MB)  AvgRuntime  \
# 0     M000  storage_performance_write         1013     2074624    1.663542
# 1  Summary                                    1013     2074624    1.663542
#
#        Cost CloudObjects
# 0  0.057296
# 1  0.057296          0.0

# %%
costW = get_process_cost(fexecW)

# %%
print(f"Cost reading: ${costR:.4f} seconds\nCost writing: ${costW:.4f} seconds")
# Out:
# Cost reading: $0.0064 seconds
# Cost writing: $0.0573 seconds
